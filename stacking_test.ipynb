# %%
import numpy as np 
import matplotlib.pyplot as plt
from astropy.io import fits
from astropy import wcs

# %matplotlib inline

FITS_DIR = "Inputs"
OUTPUT_DIR = "Outputs"
TEMPLATE = "m100_08mi.fits"

import sys
from acalib.io import container as cont
import glob
from acalib.core.transform import *
from main import stack

from numba import jit
from numpy import arange
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-aa0340d5d87e> in <module>()
#      16 from main import stack
#      17
# ---> 18 from numba import jit
#      19 from numpy import arange
#
# /home/apawn/Videos/anaconda3/lib/python3.5/site-packages/numba/__init__.py in <module>()
#       7 import sys
#       8
# ----> 9 from . import config, errors, runtests, types
#      10
#      11 # Re-export typeof
#
# /home/apawn/Videos/anaconda3/lib/python3.5/site-packages/numba/config.py in <module>()
#       9 import multiprocessing
#      10
# ---> 11 import llvmlite.binding as ll
#      12
#      13 from .errors import NumbaWarning, PerformanceWarning
#
# /home/apawn/Videos/anaconda3/lib/python3.5/site-packages/llvmlite/binding/__init__.py in <module>()
#       4 from __future__ import print_function, absolute_import
#       5
# ----> 6 from .dylib import *
#       7 from .executionengine import *
#       8 from .initfini import *
#
# /home/apawn/Videos/anaconda3/lib/python3.5/site-packages/llvmlite/binding/dylib.py in <module>()
#       2 from ctypes import c_void_p, c_char_p, c_bool, POINTER
#       3
# ----> 4 from . import ffi
#       5 from .common import _encode_string
#       6
#
# /home/apawn/Videos/anaconda3/lib/python3.5/site-packages/llvmlite/binding/ffi.py in <module>()
#      38 _lib_name = get_library_name()
#      39 try:
# ---> 40     lib = ctypes.CDLL(os.path.join(_lib_dir, _lib_name))
#      41 except OSError as e:
#      42     # Allow finding the llvmlite DLL in the current directory, for ease
#
# /home/apawn/Videos/anaconda3/lib/python3.5/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     345
#     346         if handle is None:
# --> 347             self._handle = _dlopen(self._name, mode)
#     348         else:
#     349             self._handle = handle
#
# KeyboardInterrupt:

# %%
result = fits.open(OUTPUT_DIR+"/Img_5.fits")[0].data

# %%
stack(FITS_DIR,OUTPUT_DIR,None,None,None,None)
# Out:
# Input Directory: Inputs
# Output Directory: Outputs
# Crop: /Img_0_0.fits
# Crop: /Img_0_1.fits
# Crop: /Img_0_2.fits
# Crop: /Img_0_3.fits
# Crop: /Img_0_4.fits
# Done.
# ((0, 0), (219, 86))
# Rotate: /Img_1_0.fits
# Done.
# ((0, 0), (246, 72))
# Rotate: /Img_1_1.fits
# Done.
# ((0, 0), (129, 101))
# Rotate: /Img_1_2.fits
# Done.
# ((0, 0), (44, 42))
# Rotate: /Img_1_3.fits
# Done.
# ((0, 0), (22, 21))
# Rotate: /Img_1_4.fits
# Done.
# Scale: /Img_2_0.fits
# img_scale : sqrt
# Done.
# Scale: /Img_2_1.fits
# img_scale : sqrt
# Done.
# Scale: /Img_2_2.fits
# img_scale : sqrt
# Done.
# Scale: /Img_2_3.fits
# img_scale : sqrt
# Done.
# Scale: /Img_2_4.fits
# img_scale : sqrt
# Done.
# Align: /Img_3_0.fits
# Done.
# Align: /Img_3_1.fits
# Done.
# Align: /Img_3_2.fits
# Done.
# Align: /Img_3_3.fits
# Done.
# Align: /Img_3_4.fits
# Done.
# Stack: Done.

# %%
def show(fname):
    result = fits.open(OUTPUT_DIR+"/"+fname)[0].data

    #load template
    fig = plt.figure(figsize=(8,8))
    fig.add_subplot(111)
    plt.title(fname)
    plt.imshow(result)

show("Img_4_1.fits")
show("Img_4_2.fits")
show("Img_5.fits")
#load fits files
#files = glob.glob(FITS_DIR+"*.fits")
#c = cont.Container()
#for i in files:
#    fit_file = fits.open(i)[0].data
#    data = fit_file[0].data
#    c.load_fits(i)
#    
#    fits_file.close()

# %%
from acalib.core.transform import *
from stacking import *
c = cont.Container()
path = 'fits/M1-dss2b.fits'
files = glob.glob('../fits/*.fits')

template = fits.open(path)[0].data

for i in files:
    c.load_fits(i)
    

result, snr = stacking(template,c)

# %%
fig = plt.figure()
fig.add_subplot(111)
plt.imshow(result)
plt.show()

# %%
import acalib
st = acalib.Stacking()
result2, snr2 = st.run(template,c)

# %%
fig.add_subplot(121)
plt.imshow(result2)
plt.show()
